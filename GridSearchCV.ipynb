# %% [markdown]
# <a href="https://colab.research.google.com/github/heyibad/ai-engineering-projects/blob/main/GridSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df["species"].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['species'])
y = df['species']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=5)

# %%
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model_knn.score(X_test, y_test)
# Out:
# 0.98

# %%
from sklearn.svm import SVC

model_svm = SVC(C=30, gamma="auto",kernel='rbf')

# %%
model_svm.fit(X_train, y_train)

model_svm.score(X_test, y_test)
# Out:
# 0.98

# %%
from sklearn.model_selection import GridSearchCV

classifer = GridSearchCV((model_svm),{
    "C":[1,2,10,20,30],
    "kernel":['rbf','linear']
}, cv=5, return_train_score=False)

# %%
classifer.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'),
#              param_grid={'C': [1, 2, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
res =pd.DataFrame(classifer.cv_results_)

# %%
res
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.005123      0.001443         0.003405        0.000412        1
# 1       0.004122      0.000123         0.003865        0.000978        1
# 2       0.004159      0.000193         0.003400        0.000662        2
# 3       0.004636      0.001349         0.002991        0.000075        2
# 4       0.004670      0.001400         0.002986        0.000052       10
# 5       0.003759      0.000099         0.002967        0.000330       10
# 6       0.004479      0.000708         0.002992        0.000213       20
# 7       0.003915      0.000061         0.003040        0.000165       20
# 8       0.004633      0.001214         0.002942        0.000184       30
# 9       0.004031      0.000114         0.002968        0.000172       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# ...

# %%
res[["param_C","mean_test_score","param_kernel"]]
# Out:
#    param_C  mean_test_score param_kernel
# 0        1         0.980000          rbf
# 1        1         0.980000       linear
# 2        2         0.980000          rbf
# 3        2         0.980000       linear
# 4       10         0.980000          rbf
# 5       10         0.973333       linear
# 6       20         0.966667          rbf
# 7       20         0.966667       linear
# 8       30         0.960000          rbf
# 9       30         0.960000       linear

# %%
from sklearn.model_selection import RandomizedSearchCV

classifer = RandomizedSearchCV((model_svm),{
    "C":[1,2,10,20,4,6,30],
    "kernel":['rbf','linear']
}, n_iter=10, cv=5, return_train_score=False)
classifer.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(C=30, gamma='auto'),
#                    param_distributions={'C': [1, 2, 10, 20, 4, 6, 30],
#                                         'kernel': ['rbf', 'linear']})

# %%
pd.DataFrame(classifer.cv_results_)[["param_C","mean_test_score","param_kernel"]]
# Out:
#    param_C  mean_test_score param_kernel
# 0       10         0.973333       linear
# 1        1         0.980000          rbf
# 2        6         0.980000          rbf
# 3       30         0.960000          rbf
# 4       10         0.980000          rbf
# 5        2         0.980000          rbf
# 6        2         0.980000       linear
# 7       20         0.966667       linear
# 8       20         0.966667          rbf
# 9        1         0.980000       linear
